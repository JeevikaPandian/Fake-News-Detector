# %% [markdown]
# <a href="https://colab.research.google.com/github/JeevikaPandian/Fake-News-Detector/blob/main/FakeNewsDetector1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Save the current notebook to a file if not already saved
import os
from google.colab import files

# Save notebook to root as a test
files.download('FakeNewsDetector.ipynb')

# %%
import zipfile

zip_path = "/content/drive/MyDrive/archive.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("/content/fake_news_data")

# %%
import pandas as pd

#Load The Dataset
fake_df = pd.read_csv("/content/fake_news_data/Fake.csv")
true_df = pd.read_csv("/content/fake_news_data/True.csv")

# Add labels
fake_df["label"] = 0
true_df["label"] = 1

# Combine The Datasets
data = pd.concat([fake_df, true_df], ignore_index=True)
data = data.sample(frac=1).reset_index(drop=True)

# View sample
data.head()
# Out:
#                                                title  \
# 0  Royal Jordanian gets U.S. instructions lifting...
# 1  “LITTLE” MARCO RUBIO GRILLS Trump’s Secretary ...
# 2  Mueller team lawyer brings witness-flipping ex...
# 3  California governor endorses Clinton, calls Tr...
# 4   The NFL Puts Trump In A VERY Awkward Position...
#
#                                                 text          subject  \
# 0  AMMAN (Reuters) - Jordanian airline Royal Jord...     politicsNews
# 1                                                     Government News
# 2  (Reuters) - A veteran federal prosecutor recru...     politicsNews
# 3  WASHINGTON (Reuters) - California Governor Jer...     politicsNews
# 4  The presidential debate schedule is already ou...             News
#
#                 date  label
# 0  February 4, 2017       1
# 1       Jan 11, 2017      0
# 2     June 19, 2017       1
# 3      May 31, 2016       1
# 4      July 31, 2016      0
